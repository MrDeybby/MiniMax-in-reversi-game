# %%
import pandas as pd

# %%
genetic_data = pd.read_csv("output/genetic_vs_3.csv")

# %%
genetic_data["player 1"].value_counts()
# Out:
# player 1
# {'apertura': {'corner': 0.1141, 'mob': 0.6328, 'stable': 0.3379, 'parity': 0.9211, 'pos': 0.102}, 'medio': {'corner': 0.8077, 'mob': 0.5559, 'stable': 0.6918342811648904, 'parity': 0.4097, 'pos': 0.3183}, 'final': {'corner': 0.1662, 'mob': 0.831, 'stable': 0.4163, 'parity': 0.5333, 'pos': 0.6764}}      10
# {'apertura': {'corner': 0.4033, 'mob': 0.4844, 'stable': 0.4534, 'parity': 0.7111, 'pos': 0.3628}, 'medio': {'corner': 0.4561, 'mob': 0.7731, 'stable': 0.8084, 'parity': 0.8716, 'pos': 0.2125}, 'final': {'corner': 0.2062, 'mob': 0.6556, 'stable': 0.236, 'parity': 0.5923, 'pos': 0.7982}}                  7
# {'apertura': {'corner': 0.0806, 'mob': 0.3481, 'stable': 0.6498, 'parity': 0.9519, 'pos': 0.0583}, 'medio': {'corner': 0.6825, 'mob': 0.9393, 'stable': 0.8581, 'parity': 0.8179, 'pos': 0.2365}, 'final': {'corner': 0.0209, 'mob': 0.9103, 'stable': 0.3316, 'parity': 0.457, 'pos': 0.9795}}                  7
# ...

# %%
# weights 4
genetic_data[genetic_data["player 1"] == "{'apertura': {'corner': 0.1141, 'mob': 0.6328, 'stable': 0.3379, 'parity': 0.9211, 'pos': 0.102}, 'medio': {'corner': 0.8077, 'mob': 0.5559, 'stable': 0.6918342811648904, 'parity': 0.4097, 'pos': 0.3183}, 'final': {'corner': 0.1662, 'mob': 0.831, 'stable': 0.4163, 'parity': 0.5333, 'pos': 0.6764}}"]
# Out:
#                                               player 1      player 2  \
# 25   {'apertura': {'corner': 0.1141, 'mob': 0.6328,...   heuristic_2
# 32   {'apertura': {'corner': 0.1141, 'mob': 0.6328,...    bad_player
# 48   {'apertura': {'corner': 0.1141, 'mob': 0.6328,...  minimax_base
# 68   {'apertura': {'corner': 0.1141, 'mob': 0.6328,...        random
# 80   {'apertura': {'corner': 0.1141, 'mob': 0.6328,...        greedy
# 111  {'apertura': {'corner': 0.1141, 'mob': 0.6328,...   heuristic_2
# 112  {'apertura': {'corner': 0.1141, 'mob': 0.6328,...    bad_player
# 135  {'apertura': {'corner': 0.1141, 'mob': 0.6328,...  minimax_base
# 150  {'apertura': {'corner': 0.1141, 'mob': 0.6328,...        random
# 164  {'apertura': {'corner': 0.1141, 'mob': 0.6328,...        greedy
#
#                                                 winner  winner points  \
# 25   {'apertura': {'corner': 0.1141, 'mob': 0.6328,...           49.0
# ...

# %%
# weights 5
genetic_data[genetic_data["player 1"] == "{'apertura': {'corner': 0.4033, 'mob': 0.4844, 'stable': 0.4534, 'parity': 0.7111, 'pos': 0.3628}, 'medio': {'corner': 0.4561, 'mob': 0.7731, 'stable': 0.8084, 'parity': 0.8716, 'pos': 0.2125}, 'final': {'corner': 0.2062, 'mob': 0.6556, 'stable': 0.236, 'parity': 0.5923, 'pos': 0.7982}}"]
# Out:
#                                               player 1      player 2  \
# 29   {'apertura': {'corner': 0.4033, 'mob': 0.4844,...   heuristic_2
# 34   {'apertura': {'corner': 0.4033, 'mob': 0.4844,...    bad_player
# 51   {'apertura': {'corner': 0.4033, 'mob': 0.4844,...  minimax_base
# 64   {'apertura': {'corner': 0.4033, 'mob': 0.4844,...        random
# 86   {'apertura': {'corner': 0.4033, 'mob': 0.4844,...        greedy
# 105  {'apertura': {'corner': 0.4033, 'mob': 0.4844,...   heuristic_2
# 118  {'apertura': {'corner': 0.4033, 'mob': 0.4844,...    bad_player
#
#                                                 winner  winner points  \
# 29   {'apertura': {'corner': 0.4033, 'mob': 0.4844,...           42.0
# 34   {'apertura': {'corner': 0.4033, 'mob': 0.4844,...           36.0
# 51   {'apertura': {'corner': 0.4033, 'mob': 0.4844,...           34.0
# 64   {'apertura': {'corner': 0.4033, 'mob': 0.4844,...           49.0
# ...

# %%
# weights 6
genetic_data[genetic_data["player 1"] == "{'apertura': {'corner': 0.0806, 'mob': 0.3481, 'stable': 0.6498, 'parity': 0.9519, 'pos': 0.0583}, 'medio': {'corner': 0.6825, 'mob': 0.9393, 'stable': 0.8581, 'parity': 0.8179, 'pos': 0.2365}, 'final': {'corner': 0.0209, 'mob': 0.9103, 'stable': 0.3316, 'parity': 0.457, 'pos': 0.9795}}"]
# Out:
#                                               player 1      player 2  \
# 4    {'apertura': {'corner': 0.0806, 'mob': 0.3481,...        greedy
# 16   {'apertura': {'corner': 0.0806, 'mob': 0.3481,...   heuristic_2
# 41   {'apertura': {'corner': 0.0806, 'mob': 0.3481,...    bad_player
# 52   {'apertura': {'corner': 0.0806, 'mob': 0.3481,...  minimax_base
# 66   {'apertura': {'corner': 0.0806, 'mob': 0.3481,...        random
# 83   {'apertura': {'corner': 0.0806, 'mob': 0.3481,...        greedy
# 103  {'apertura': {'corner': 0.0806, 'mob': 0.3481,...   heuristic_2
#
#                                                 winner  winner points  \
# 4                                                  NaN            NaN
# 16   {'apertura': {'corner': 0.0806, 'mob': 0.3481,...           52.0
# 41   {'apertura': {'corner': 0.0806, 'mob': 0.3481,...           41.0
# 52   {'apertura': {'corner': 0.0806, 'mob': 0.3481,...           47.0
# ...
